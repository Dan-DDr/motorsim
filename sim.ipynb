# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
print(os.getcwd())
os.system("build\\MOTORSIM.exe 100000 0.00001")
# Out:
# c:\Users\shrey\OneDrive\Documents\MMS\motorsim
# 0

# %%
dctrl = pd.read_csv("dctrl.csv").values
qctrl = pd.read_csv("qctrl.csv").values
motor = pd.read_csv("motor.csv").values

# %%
plt.plot(dctrl[:, 0], dctrl[:, 1])
plt.plot(dctrl[:, 0], dctrl[:, 2])
plt.legend(["Error", "Output"])
# plt.xlim([0, 0.015])
plt.figure()
plt.plot(motor[:, 0], motor[:, 1])

# %%
plt.plot(dctrl[:, 0], qctrl[:, 1])
plt.plot(dctrl[:, 0], qctrl[:, 2])
plt.legend(["Error", "Output"])
plt.figure()
plt.plot(motor[:, 0], motor[:, 2])

# %%
plt.figure()
plt.plot(motor[:, 0], motor[:, 4])
plt.figure()
plt.plot(motor[:, 0], motor[:, 5])
